# %%
import os

# %%
a =

# %%
a
# Out:
# <generator object walk at 0x000001F34C571848>

# %%
for path, j, files in os.walk("."):
#     print(os.path.join(i, k))
    for file in files:
        print(os.path.join(path, file))
        if file.endswith(".jpg"):
            os.rename(os.path.join(path, file), os.path.join(path, "1.jpg"))
# Out:
# .\Untitled.ipynb
# .\.ipynb_checkpoints\Untitled-checkpoint.ipynb
# .\Acadian_Flycatcher\Acadian_Flycatcher_0066_29190.jpg
# .\American_Crow\American_Crow_0117_25090.jpg
# .\American_Goldfinch\American_Goldfinch_0074_32265.jpg
# .\American_Pipit\American_Pipit_0039_99841.jpg
# .\American_Redstart\American_Redstart_0094_103425.jpg
# .\American_Three_toed_Woodpecker\American_Three_Toed_Woodpecker_0048_796163.jpg
# .\Anna_Hummingbird\Anna_Hummingbird_0106_56335.jpg
# .\Artic_Tern\Artic_Tern_0032_141313.jpg
# .\Baird_Sparrow\Baird_Sparrow_0009_106882.jpg
# .\Baltimore_Oriole\Baltimore_Oriole_0127_87560.jpg
# .\Bank_Swallow\Bank_Swallow_0015_129853.jpg
# .\Barn_Swallow\Barn_Swallow_0038_132780.jpg
# .\Bay_breasted_Warbler\Bay_Breasted_Warbler_0026_159744.jpg
# .\Belted_Kingfisher\Belted_Kingfisher_0020_70922.jpg
# .\Bewick_Wren\Bewick_Wren_0056_184834.jpg
# .\Black_and_white_Warbler\Black_And_White_Warbler_0031_160773.jpg
# .\Black_billed_Cuckoo\Black_Billed_Cuckoo_0071_26288.jpg
# ...
